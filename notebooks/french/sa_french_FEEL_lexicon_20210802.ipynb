# %% [markdown]
# # **French Sentiment Analysis with FEEL Lexicon**
#
# * https://github.com/shalinijaiswalsj09/French-Language-Processing-

# %%
# !git clone https://github.com/shalinijaiswalsj09/French-Language-Processing-.git
# Out:
# Cloning into 'French-Language-Processing-'...
# remote: Enumerating objects: 8, done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 8
# Unpacking objects: 100% (8/8), done.

# %%
# !ls
# Out:
# French-Language-Processing-  sample_data
